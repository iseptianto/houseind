# %% [markdown]
# # 🏠 House Data Exploration
# This notebook performs initial data exploration on the `house_data.csv` dataset.

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('/content/edit.csv')

# ℹ️ Display basic information about the dataset
print(f"📐 Dataset shape (rows, columns): {df.shape}")
print("\n📊 Dataset Info:")
print(df.info())
# Out:
# 📐 Dataset shape (rows, columns): (2648, 8)
#
# 📊 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2648 entries, 0 to 2647
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Luas Tanah     2648 non-null   float64
#  1   KM             2648 non-null   object
#  2   KT             2648 non-null   object
#  3   Luas Bangunan  2648 non-null   float64
#  4   Price          2646 non-null   object
#  5   Kota/Kab       2648 non-null   object
#  6   Provinsi       2648 non-null   object
#  7   Type           2648 non-null   object
# dtypes: float64(2), object(6)
# memory usage: 165.6+ KB
# None

# %%
# ❓ Checking for missing values to identify data quality issues
print("\n🔍 Missing values per column:")
print(df.isnull().sum())
# Out:
# 🔍 Missing values per column:
# Luas Tanah       0
# KM               0
# KT               0
# Luas Bangunan    0
# Price            2
# Kota/Kab         0
# Provinsi         0
# Type             0
# dtype: int64

# %%
# 📈 Descriptive statistics like mean, std deviation, min, max, etc.
print("\n📋 Statistical Summary:")
print(df.describe())
# Out:
# 📋 Statistical Summary:
#          Luas Tanah  Luas Bangunan
# count   2648.000000   2.648000e+03
# mean     245.423678   2.068039e+03
# std      496.530885   9.716203e+04
# min        0.000000   0.000000e+00
# 25%       98.000000   7.000000e+01
# 50%      140.000000   1.200000e+02
# 75%      226.500000   2.000000e+02
# max    11340.000000   5.000000e+06

# %%
# Calculate the median of the 'Luas Tanah' column
median_luas_tanah = df['Luas Tanah'].median()

# Replace 0 values in 'Luas Tanah' with the median
df['Luas Tanah'] = df['Luas Tanah'].replace(0, median_luas_tanah)

print(f"🔄 Replaced 0 values in 'Luas Tanah' with the median ({median_luas_tanah}).")

# Display descriptive statistics for 'Luas Tanah' to verify the change
print("\n📋 Statistical Summary for 'Luas Tanah' after replacing 0s:")
print(df['Luas Tanah'].describe())
# Out:
# 🔄 Replaced 0 values in 'Luas Tanah' with the median (140.0).
#
# 📋 Statistical Summary for 'Luas Tanah' after replacing 0s:
# count     2648.000000
# mean       252.455400
# std        493.989335
# min         14.000000
# 25%        105.000000
# 50%        140.000000
# 75%        226.500000
# max      11340.000000
# Name: Luas Tanah, dtype: float64

# %%
# Calculate the median of the 'Luas Tanah' column
median_luas_tanah = df['Luas Bangunan'].median()

# Replace 0 values in 'Luas Tanah' with the median
df['Luas Bangunan'] = df['Luas Bangunan'].replace(0, median_luas_tanah)

print(f"🔄 Replaced 0 values in 'Luas Bangunan' with the median ({median_luas_tanah}).")

# Display descriptive statistics for 'Luas Tanah' to verify the change
print("\n📋 Statistical Summary for 'Luas Bangunan' after replacing 0s:")
print(df['Luas Bangunan'].describe())
# Out:
# 🔄 Replaced 0 values in 'Luas Bangunan' with the median (120.0).
#
# 📋 Statistical Summary for 'Luas Bangunan' after replacing 0s:
# count    2.648000e+03
# mean     2.069262e+03
# std      9.716200e+04
# min      1.000000e+00
# 25%      7.200000e+01
# 50%      1.200000e+02
# 75%      2.000000e+02
# max      5.000000e+06
# Name: Luas Bangunan, dtype: float64

# %%
# 💰 Visualizing the distribution of house Luas Tanah
plt.figure(figsize=(10, 6))
sns.histplot(df['Luas Tanah'], kde=True)
plt.title('House Luas Tanah Distribution')
plt.xlabel('Luas Tanah')
plt.ylabel('Frequency')
plt.show()

print("📊 Plotted house price distribution.")
# Out:
# 📊 Plotted house price distribution.

# %%
# 🔗 Checking how features are correlated with each other
plt.figure(figsize=(12, 8))
correlation_matrix = df.select_dtypes(include=np.number).corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Feature Correlation Matrix')
plt.show()

print("📈 Displayed feature correlation heatmap.")
# Out:
# 📈 Displayed feature correlation heatmap.

# %%
# 📍 Bar chart to see how many houses exist in each Type
plt.figure(figsize=(10, 6))
sns.countplot(x='Type', data=df)
plt.title('Houses by Type')
plt.xlabel('Type')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

print("📍 Visualized distribution of houses by location.")
# Out:
# 📍 Visualized distribution of houses by location.

# %%
# 📍 Bar chart to see how many houses exist in each location
plt.figure(figsize=(10, 6))
sns.countplot(x='Provinsi', data=df)
plt.title('Houses by Provinsi')
plt.xlabel('Provinsi')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

print("📍 Visualized distribution of houses by location.")
# Out:
# 📍 Visualized distribution of houses by location.

# %%
# 📍 Bar chart to see how many houses exist in each location
plt.figure(figsize=(10, 6))
sns.countplot(x='KT', data=df)
plt.title('Houses by KT')
plt.xlabel('KT')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

print("📍 Visualized distribution of houses by location.")
# Out:
# 📍 Visualized distribution of houses by location.

# %%
# 📍 Bar chart to see how many houses exist in each location
plt.figure(figsize=(10, 6))
sns.countplot(x='KM', data=df)
plt.title('Houses by Kamar Mandi')
plt.xlabel('Kamar Mandi')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

print("📍 Visualized distribution of houses by location.")
# Out:
# 📍 Visualized distribution of houses by location.

# %%
# 🛏️ Bar chart showing how average house price varies by bedroom count
plt.figure(figsize=(10, 6))
sns.barplot(x='KT', y='KM', data=df)
plt.title('Average Price by Number of Rooms (KT)')
plt.xlabel('Number of Rooms (KT)')
plt.ylabel('Kamar Mandi')
plt.show()

print("🛏️ Compared average prices based on bedroom count.")
# Out:
# 🛏️ Compared average prices based on bedroom count.

# %%
# Next Step
# Feature Engineering
# Create new features or modify existing ones

# %%
df.describe()
# Out:
#          Luas Tanah  Luas Bangunan
# count   2648.000000   2.648000e+03
# mean     252.455400   2.069262e+03
# std      493.989335   9.716200e+04
# min       14.000000   1.000000e+00
# 25%      105.000000   7.200000e+01
# 50%      140.000000   1.200000e+02
# 75%      226.500000   2.000000e+02
# max    11340.000000   5.000000e+06

# %%
# Save the cleaned DataFrame to a new CSV file
df.to_csv('cleaned_house_data.csv', index=False)

print("✅ Cleaned data saved to 'cleaned_house_data.csv'")
# Out:
# ✅ Cleaned data saved to 'cleaned_house_data.csv'
